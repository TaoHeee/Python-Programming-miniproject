# %%
friends = open("friends.txt","r")

# %%
friend = list(friends)
friend
# Out:
# ['Ana\n',
#  '801-456-789\n',
#  'Ben\n',
#  '609 4567890\n',
#  'Cory\n',
#  '(206)-345-2619\n',
#  'Danny\n',
#  '6095648765']

# %%
import re

# %%
for i in range(0,len(friend)):
   if i % 2 == 0: friend[i]=friend[i].replace("\n","")
   else: friend[i]=re.sub("\D","",friend[i])

# %%
friend
# Out:
# ['Ana',
#  '801456789',
#  'Ben',
#  '6094567890',
#  'Cory',
#  '2063452619',
#  'Danny',
#  '6095648765']

# %%
maps = open("map_areacodes_states.txt","r")

# %%
fmap = list(maps)
fmap
# Out:
# ['201\n',
#  'New Jersey\n',
#  '202\n',
#  'Washington D.C.\n',
#  '203\n',
#  'Connecticut\n',
#  '204\n',
#  'Canada - Manitoba\n',
#  '205\n',
#  'Alabama\n',
#  '206\n',
#  'Washington\n',
#  '207\n',
#  'Maine\n',
#  '208\n',
#  'Idaho\n',
#  '209\n',
#  'California\n',
#  '210\n',
#  'Texas\n',
#  '212\n',
#  'New York\n',
#  '213\n',
#  'California\n',
#  '214\n',
#  'Texas\n',
#  '215\n',
#  'Pennsylvania\n',
#  '216\n',
#  'Ohio\n',
#  '217\n',
#  'Illinois\n',
#  '218\n',
#  'Minnesota\n',
#  '219\n',
#  'Indiana\n',
#  '220\n',
#  'Ohio\n',
#  '224\n',
#  'Illinois\n',
#  '225\n',
#  'Louisiana\n',
#  '226\n',
#  'Canada - Ontario\n',
#  '228\n',
#  'Mississippi\n',
#  '229\n',
#  'Georgia\n',
#  '231\n',
#  'Michigan\n',
#  '234\n',
#  'Ohio\n',
#  '236\n',
#  'Canada - British Columbia\n',
#  '239\n',
#  'Florida\n',
#  '240\n',
#  'Maryland\n',
#  '242\n',
#  'Bahamas\n',
#  '246\n',
#  'Barbados\n',
#  '248\n',
#  'Michigan\n',
#  '249\n',
#  'Canada - Ontario\n',
# ...

# %%
for i in range(0,len(fmap)):
   if i % 2 == 1: fmap[i]=fmap[i].replace("\n","")
   else: fmap[i]=re.sub("\D","",fmap[i])

# %%
fmap
# Out:
# ['201',
#  'New Jersey',
#  '202',
#  'Washington D.C.',
#  '203',
#  'Connecticut',
#  '204',
#  'Canada - Manitoba',
#  '205',
#  'Alabama',
#  '206',
#  'Washington',
#  '207',
#  'Maine',
#  '208',
#  'Idaho',
#  '209',
#  'California',
#  '210',
#  'Texas',
#  '212',
#  'New York',
#  '213',
#  'California',
#  '214',
#  'Texas',
#  '215',
#  'Pennsylvania',
#  '216',
#  'Ohio',
#  '217',
#  'Illinois',
#  '218',
#  'Minnesota',
#  '219',
#  'Indiana',
#  '220',
#  'Ohio',
#  '224',
#  'Illinois',
#  '225',
#  'Louisiana',
#  '226',
#  'Canada - Ontario',
#  '228',
#  'Mississippi',
#  '229',
#  'Georgia',
#  '231',
#  'Michigan',
#  '234',
#  'Ohio',
#  '236',
#  'Canada - British Columbia',
#  '239',
#  'Florida',
#  '240',
#  'Maryland',
#  '242',
#  'Bahamas',
#  '246',
#  'Barbados',
#  '248',
#  'Michigan',
#  '249',
#  'Canada - Ontario',
#  '250',
#  'Canada - British Columbia',
#  '251',
#  'Alabama',
#  '252',
#  'North Carolina',
#  '253',
#  'Washington',
#  '254',
# ...

# %%
def findlocation(s):
    s=s[0:3]
    for i in range(0,len(fmap)-1):
       if i % 2 == 0: 
        if fmap[i]==s: print(fmap[i+1])
    return

# %%
for i in range(0,len(friend)):
   if i % 2 == 0: print(friend[i],":")
   else: findlocation(friend[i])
# Out:
# Ana :
# Utah
# Ben :
# New Jersey
# Cory :
# Washington
# Danny :
# New Jersey
